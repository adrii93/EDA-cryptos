# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ## <span style="color:purple">LAS CRIPTOMONEDAS</span>

# %% [markdown]
# ## TEMA

# %% [markdown]
# ## <span style="color:purple">Inversión en Criptomonedas</span>

# %% [markdown]
# ## HIPÓTESIS

# %% [markdown]
# #### <span style="color:purple">¿Es seguro y rentable invertir en Criptomonedas?</span>

# %%
# hipotesis_2 = ""
# hipotesis_3 = ""

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
AAVE = pd.read_csv('AAVE-USD.csv')
BNB = pd.read_csv('BNB-USD.csv')
BTC = pd.read_csv('BTC-USD.csv')
ADA = pd.read_csv('ADA-USD.csv')
LINK = pd.read_csv('LINK-USD.csv')
ATOM = pd.read_csv('ATOM-USD.csv')
CRO = pd.read_csv('CRO-USD.csv')
DOGE = pd.read_csv('DOGE-USD.csv')
EOS = pd.read_csv('EOS-USD.csv')
ETH = pd.read_csv('ETH-USD.csv')
MIOTA = pd.read_csv('MIOTA-USD.csv')
LTC = pd.read_csv('LTC-USD.csv')
XMR = pd.read_csv('XMR-USD.csv')
XEM = pd.read_csv('XEM-USD.csv')
DOT = pd.read_csv('DOT-USD.csv')
SOL = pd.read_csv('SOL-USD.csv')
XLM = pd.read_csv('XLM-USD.csv')
USDT = pd.read_csv('USDT-USD.csv')
TRX = pd.read_csv('TRX-USD.csv')
UNI = pd.read_csv('UNI-USD.csv')
USDC = pd.read_csv('USDC-USD.csv')
XRP = pd.read_csv('XRP-USD.csv')

fuente_1 = "https://www.kaggle.com/datasets/lasaljaywardena/global-cryptocurrency-price-database"

all_cryptos = pd.concat([AAVE,BNB,BTC,ADA,LINK,ATOM,CRO,DOGE,EOS,ETH,MIOTA,LTC,XMR,XEM,DOT,SOL,XLM,USDT,TRX,UNI,USDC,XRP], ignore_index=True)
all_cryptos_except = pd.concat([AAVE,BNB,ADA,LINK,ATOM,CRO,DOGE,EOS,MIOTA,XMR,XEM,DOT,SOL,XLM,USDT,TRX,UNI,USDC,XRP], ignore_index=True)

# df_3 = pd.DataFrame()
# fuente_3 = ""

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
BTC.head()
# Out:
#           Name   Symbol        Date        Open        High         Low  \
# 0  Bitcoin USD  BTC-USD  2014-09-17  465.864014  468.174011  452.421997
# 1  Bitcoin USD  BTC-USD  2014-09-18  456.859985  456.859985  413.104004
# 2  Bitcoin USD  BTC-USD  2014-09-19  424.102997  427.834991  384.532013
# 3  Bitcoin USD  BTC-USD  2014-09-20  394.673004  423.295990  389.882996
# 4  Bitcoin USD  BTC-USD  2014-09-21  408.084991  412.425995  393.181000
#
#         Close   Adj Close    Volume
# 0  457.334015  457.334015  21056800
# 1  424.440002  424.440002  34483200
# 2  394.795990  394.795990  37919700
# 3  408.903992  408.903992  36863600
# 4  398.821014  398.821014  26580100

# %%
all_cryptos
# Out:
#            Name    Symbol        Date       Open       High        Low  \
# 0      Aave USD  AAVE-USD  2020-10-02   0.000000   0.516571   0.000000
# 1      Aave USD  AAVE-USD  2020-10-03   0.523836  65.305939   0.523801
# 2      Aave USD  AAVE-USD  2020-10-04  53.179859  55.070354  50.688992
# 3      Aave USD  AAVE-USD  2020-10-05  52.675034  55.112358  49.787899
# 4      Aave USD  AAVE-USD  2020-10-06  53.291969  53.402271  40.734577
# ...         ...       ...         ...        ...        ...        ...
# 45256   XRP USD   XRP-USD  2023-10-20   0.522982   0.529072   0.510120
# 45257   XRP USD   XRP-USD  2023-10-21   0.515393   0.529482   0.512345
# 45258   XRP USD   XRP-USD  2023-10-22   0.520979   0.523571   0.516026
# 45259   XRP USD   XRP-USD  2023-10-23   0.522797   0.538061   0.520995
# 45260   XRP USD   XRP-USD  2023-10-24   0.547622   0.581254   0.537571
#
#            Close  Adj Close      Volume
# 0       0.516571   0.516571           0
# ...
